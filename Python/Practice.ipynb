# %% [markdown]
# # Practice Notebook

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# ## Variables in Python
# It is just like a container to store data values.
# x (variable) = 24 (value)

# %%
x = 24
print(x)
# Out:
# 24

# %%
# c
type(x)
# Out:
# int

# %%
y = 'Green Tea'
print(y)
# Out:
# Green Tea

# %%
type(y)
# Out:
# str

# %%
print(y)
# Out:
# Green Tea

# %%
y = 'Matcha'
print(y)
# Out:
# Matcha
